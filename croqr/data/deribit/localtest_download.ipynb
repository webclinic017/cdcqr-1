# %%
from croqr.data.deribit.config import DeribitSampleDataUrl, get_deribit_sample_data_url
from croqr.common.config import DATA_CACHE_DIR
import urllib.request 
import os
import pandas as pd
from croqr.data.deribit.data_utils import url_csv_zip_file_reader

# %%
url = get_deribit_sample_data_url('PERPETUALS', 'trades')

# %%
url
# Out:
# 'https://csv.tardis.dev/samples/Deribit_PERPETUALS_trades_2020-07-01_2020-07-31.csv.gz'

# %%
file_name = url.split('/')[-1]
file_path = os.path.join(DATA_CACHE_DIR, file_name)

display(file_path)
# Out:
# 'C:\\Users\\Wang\\Documents\\GitHub\\data\\Deribit_PERPETUALS_trades_2020-07-01_2020-07-31.csv.gz'

# %%
urllib.request.urlretrieve(url, file_path)

# %%
opener = urllib.request.URLopener()
opener.addheader('User-Agent', 'whatever')
_ = opener.retrieve(url, file_path)

# %%
large_file = "C:\\Users\\Wang\\Documents\\GitHub\\data\\Deribit_PERPETUALS_book_snapshot_50_2020-07-01_2020-07-31.csv.gz"
os.path.getsize("C:\\Users\\Wang\\Documents\\GitHub\\data\\Deribit_PERPETUALS_book_snapshot_50_2020-07-01_2020-07-31.csv.gz")
# Out:
# 3429653900

# %%
url_csv_zip_file_reader(large_file)
# Out:
# loading cached C:\Users\Wang\Documents\GitHub\data\Deribit_PERPETUALS_book_snapshot_50_2020-07-01_2020-07-31.csv.gz
# file size > 500MB, load top 500 rows
# C:\Users\Wang\Documents\GitHub\data\Deribit_PERPETUALS_book_snapshot_50_2020-07-01_2020-07-31.csv.gz not exists!

# %%
pd.read_csv()

# %%
pd.read_csv(large_file, compression="gzip", index_col=0, quotechar='"', nrows=5000)
# Out:
#                  symbol         timestamp   local_timestamp  asks[0].price  \
# exchange
# deribit   ETH-PERPETUAL  1593561600154000  1593561600165998         225.55
# deribit   BTC-PERPETUAL  1593561600123000  1593561600185656        9133.00
# deribit   BTC-PERPETUAL  1593561600173000  1593561600212005        9133.00
# deribit   BTC-PERPETUAL  1593561600174000  1593561600216969        9133.00
# deribit   BTC-PERPETUAL  1593561600175000  1593561600216991        9133.00
# ...                 ...               ...               ...            ...
# deribit   ETH-PERPETUAL  1593561676199000  1593561676220470         225.35
# deribit   BTC-PERPETUAL  1593561676201000  1593561676221209        9129.00
# deribit   BTC-PERPETUAL  1593561676204000  1593561676221224        9129.00
# deribit   BTC-PERPETUAL  1593561676205000  1593561676221225        9129.00
# deribit   BTC-PERPETUAL  1593561676207000  1593561676221227        9129.00
#
#           asks[0].amount  asks[1].price  asks[1].amount  asks[2].price  \
# exchange
# deribit             6809          225.6            7574         225.65
# deribit            42520         9133.5              90        9134.00
# deribit            42520         9133.5              90        9134.00
# deribit            42520         9133.5              90        9134.00
# deribit            42520         9133.5              90        9134.00
# ...                  ...            ...             ...            ...
# deribit            16406          225.4            9809         225.45
# deribit           167430         9129.5           25400        9130.00
# deribit           164430         9129.5           25400        9130.00
# deribit           164430         9129.5           25400        9130.00
# deribit           164430         9129.5           25400        9130.00
#
#           asks[2].amount  asks[3].price  ...  bids[45].price  bids[45].amount  \
# exchange                                 ...
# deribit            38476          225.7  ...          222.80              160
# deribit              250         9134.5  ...         9110.00            26460
# deribit              250         9134.5  ...         9110.00            26460
# deribit              250         9134.5  ...         9110.00            26460
# deribit              250         9134.5  ...         9110.00            26460
# ...                  ...            ...  ...             ...              ...
# deribit            49906          225.5  ...          222.35             4447
# deribit             1550         9130.5  ...         9105.50            28120
# deribit             1550         9130.5  ...         9105.50            28120
# deribit             1550         9130.5  ...         9105.50            28120
# deribit             1550         9130.5  ...         9105.50            28120
#
#           bids[46].price  bids[46].amount  bids[47].price  bids[47].amount  \
# exchange
# deribit           222.70             4454          222.60            61730
# deribit          9109.00            36870         9108.50            13990
# deribit          9109.00            36870         9108.50            13990
# deribit          9109.00            36870         9108.50            13990
# deribit          9109.00            36870         9108.50            13990
# ...                  ...              ...             ...              ...
# deribit           222.15             4443          222.05             1000
# deribit          9105.00            25360         9104.50              320
# deribit          9105.00            25360         9104.50              320
# deribit          9105.00            25360         9104.50              320
# deribit          9105.00            25360         9104.50              320
#
#           bids[48].price  bids[48].amount  bids[49].price  bids[49].amount
# exchange
# deribit            222.5            93965          222.45            16335
# deribit           9108.0            41880         9107.50           170540
# deribit           9108.0            41880         9107.50           170540
# deribit           9108.0            41880         9107.50           170540
# deribit           9108.0            41880         9107.50           170540
# ...                  ...              ...             ...              ...
# deribit            222.0             9692          221.85             4437
# deribit           9104.0              980         9103.50             1810
# deribit           9104.0              980         9103.50             1810
# deribit           9104.0              980         9103.50             1810
# deribit           9104.0              980         9103.50             1810
#
# [5000 rows x 203 columns]
