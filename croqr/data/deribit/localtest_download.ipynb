# %%
from croqr.data.deribit.config import DeribitSampleDataUrl, get_deribit_sample_data_url
from croqr.common.config import DATA_CACHE_DIR
import urllib.request 
import os
import pandas as pd
from croqr.data.deribit.data_utils import url_csv_zip_file_reader
import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
url = get_deribit_sample_data_url('PERPETUALS', 'trades')

# %%
url
# Out:
# 'https://csv.tardis.dev/samples/Deribit_PERPETUALS_trades_2020-07-01_2020-07-31.csv.gz'

# %%
file_name = url.split('/')[-1]
file_path = os.path.join(DATA_CACHE_DIR, file_name)

display(file_path)
# Out:
# 'C:\\Users\\Wang\\Documents\\GitHub\\data\\Deribit_PERPETUALS_trades_2020-07-01_2020-07-31.csv.gz'

# %%
opener = urllib.request.URLopener()
opener.addheader('User-Agent', 'whatever')
_ = opener.retrieve(url, file_path)

# %%
large_file = "C:\\Users\\Wang\\Documents\\GitHub\\data\\Deribit_PERPETUALS_book_snapshot_50_2020-07-01_2020-07-31.csv.gz"
os.path.getsize("C:\\Users\\Wang\\Documents\\GitHub\\data\\Deribit_PERPETUALS_book_snapshot_50_2020-07-01_2020-07-31.csv.gz")
# Out:
# 3429653900

# %%
url_csv_zip_file_reader(large_file)
# Out:
# loading cached C:\Users\Wang\Documents\GitHub\data\Deribit_PERPETUALS_book_snapshot_50_2020-07-01_2020-07-31.csv.gz
# file size > 500MB, load top 500 rows
# C:\Users\Wang\Documents\GitHub\data\Deribit_PERPETUALS_book_snapshot_50_2020-07-01_2020-07-31.csv.gz not exists!

# %%
pd.read_csv()

# %%
df = pd.read_csv(large_file, compression="gzip", index_col=0, quotechar='"', nrows=5000)

# %%
df[df['symbol']=='ETH-PERPETUAL'].set_index('timestamp')['asks[0].price'].iplot()
# Out:
# <div>                            <div id="3160e0fd-6d87-4c2d-8f4e-9789569b844e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("3160e0fd-6d87-4c2d-8f4e-9789569b844e")) {                    Plotly.newPlot(                        "3160e0fd-6d87-4c2d-8f4e-9789569b844e",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"asks[0].price","text":"","type":"scatter","x":[1593561600154000,1593561600463000,1593561600502000,1593561600558000,1593561601422000,1593561601438000,1593561601524000,1593561601556000,1593561601602000,1593561601616000,1593561601647000,1593561601681000,1593561601802000,1593561601835000,1593561601957000,1593561602021000,1593561602023000,1593561602058000,1593561602060000,1593561602061000,1593561602062000,1593561602062000,1593561602063000,1593561602067000,1593561602104000,1593561602132000,1593561602481000,1593561602541000,1593561602578000,1593561602618000,1593561602739000,1593561602984000,1593561603001000,1593561603002000,1593561603004000,1593561603005000,1593561603010000,1593561603016000,1593561603017000,1593561603018000,1593561603018000,1593561603028000,1593561603030000,1593561603031000,1593561603052000,1593561603090000,1593561603121000,1593561603141000,1593561603277000,1593561603279000,1593561603533000,1593561604110000,1593561604135000,1593561604195000,1593561604196000,1593561604358000,1593561604378000,1593561604416000,1593561604437000,1593561604438000,1593561604641000,1593561605012000,1593561605014000,1593561605099000,1593561605143000,1593561605210000,1593561605254000,1593561605255000,1593561605313000,1593561605452000,1593561605506000,1593561605593000,1593561605844000,1593561605901000,1593561606422000,1593561606438000,1593561606456000,1593561606470000,1593561606482000,1593561606674000,1593561606722000,1593561606730000,1593561606750000,1593561606956000,1593561606977000,1593561606991000,1593561607023000,1593561607024000,1593561607034000,1593561607046000,1593561607056000,1593561607072000,1593561607076000,1593561607077000,1593561607107000,1593561607196000,1593561607233000,1593561607281000,1593561607299000,1593561607303000,1593561607307000,1593561607330000,1593561607331000,1593561607361000,1593561607740000,1593561607792000,1593561607881000,1593561607920000,1593561607976000,1593561608065000,1593561608066000,1593561608076000,1593561608088000,1593561608090000,1593561608090000,1593561608102000,1593561608111000,1593561608218000,1593561608305000,1593561608317000,1593561608407000,1593561608463000,1593561608559000,1593561608706000,1593561608800000,1593561608923000,1593561609042000,1593561609043000,1593561609054000,1593561609060000,1593561609095000,1593561609283000,1593561609335000,1593561609409000,1593561609410000,1593561609517000,1593561609527000,1593561609719000,1593561609768000,1593561609782000,1593561609784000,1593561609912000,1593561609977000,1593561610001000,1593561610002000,1593561610010000,1593561610019000,1593561610043000,1593561610044000,1593561610050000,1593561610051000,1593561610065000,1593561610076000,1593561610090000,1593561610100000,1593561610101000,1593561610103000,1593561610104000,1593561610105000,1593561610105000,1593561610155000,1593561610159000,1593561610230000,1593561610252000,1593561610266000,1593561610284000,1593561610370000,1593561610380000,1593561610407000,1593561610474000,1593561610531000,1593561610537000,1593561610651000,1593561610721000,1593561610756000,1593561610757000,1593561610757000,1593561610758000,1593561610758000,1593561610760000,1593561610784000,1593561610795000,1593561610802000,1593561610803000,1593561610825000,1593561610858000,1593561610895000,1593561611032000,1593561611035000,1593561611059000,1593561611060000,1593561611087000,1593561611132000,1593561611133000,1593561611135000,1593561611138000,1593561611168000,1593561611275000,1593561611626000,1593561611664000,1593561611665000,1593561611680000,1593561611709000,1593561611860000,1593561611908000,1593561611982000,1593561612089000,1593561612091000,1593561612112 ...
