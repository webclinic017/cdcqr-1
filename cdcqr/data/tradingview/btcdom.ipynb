# %%
from cdcqr.common.utils import LOCAL_DATA_DIR
import os
import pandas as pd

# %%
df0 = pd.read_csv(os.path.join(LOCAL_DATA_DIR, 'BTCDOM.csv'))
df0['t'] = pd.to_datetime(df0['time'], unit='s')
df0 = df0[['t','close']]
df0.columns = ['t','BTCDOM']
df0['BTCDOM'] = df0['BTCDOM']/100
df0 = df0.set_index('t')
df = df0[df0.index>='20200101']

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='t'>
