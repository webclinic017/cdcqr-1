# %% [markdown]
# ### Combine quote and trade data with additional features for analysis
#    * compare results for both options and PERP

# %%
from cdcqr.data.deribit.data_utils import quoto_and_trade_analysis

# %%
quoto_and_trade_analysis?
# Out:
# Signature:
# quoto_and_trade_analysis(
#     contract='BTC-8OCT21-48000-C',
#     date='2021-10-01',
#     symbol='OPTIONS',
#     exchange='deribit',
# )
# Docstring: <no docstring>
# File:      c:\users\wang\documents\github\cdcqr\cdcqr\data\deribit\data_utils.py
# Type:      function

# %% [markdown]
# #### check options

# %%
ret_dict, ret_df = quoto_and_trade_analysis( )
# Out:
# processing data BTC-8OCT21-48000-C 2021-10-01 deribit
# 'parse_optSymbol_col'  17.13 sec
# 'parse_time_col'  6.91 sec

# %%
ret_dict
# Out:
# {'num_trades': 220, 'num_midp_chg': 4877, 'num_wgtmidp_chg': 31305}

# %%
ret_df['spread'].plot()

# %%
ret_df.set_index('timestamp_dt')#['spread']
# Out:
#       exchange              symbol         timestamp   local_timestamp  \
# 0      deribit  BTC-8OCT21-48000-C  1633046399032000  1633046400368150
# 1      deribit  BTC-8OCT21-48000-C  1633046403664000  1633046403672936
# 2      deribit  BTC-8OCT21-48000-C  1633046412072000  1633046412240119
# 3      deribit  BTC-8OCT21-48000-C  1633046415023000  1633046415031956
# 4      deribit  BTC-8OCT21-48000-C  1633046465787000  1633046465795261
# ...        ...                 ...               ...               ...
# 31301  deribit  BTC-8OCT21-48000-C  1633132756563000  1633132756577408
# 31302  deribit  BTC-8OCT21-48000-C  1633132777927000  1633132777941495
# 31303  deribit  BTC-8OCT21-48000-C  1633132784730000  1633132784737550
# 31304  deribit  BTC-8OCT21-48000-C  1633132796496000  1633132796518527
# 31305  deribit  BTC-8OCT21-48000-C  1633132798343000  1633132798377247
#
#        ask_amount  ask_price  bid_price  bid_amount instrument  \
# 0            30.4     0.0100      0.009        16.7        BTC
# 1            30.4     0.0100      0.009        38.6        BTC
# 2            30.4     0.0100      0.009        37.7        BTC
# 3            30.4     0.0100      0.009        15.8        BTC
# 4            27.4     0.0100      0.009        15.8        BTC
# ...           ...        ...        ...         ...        ...
# 31301         2.1     0.0405      0.039        12.3        BTC
# 31302         2.1     0.0405      0.039        10.3        BTC
# 31303        10.6     0.0405      0.039        10.3        BTC
# 31304         2.1     0.0405      0.039        10.3        BTC
# 31305        10.4     0.0405      0.039        10.3        BTC
#
#                    expire  ...            timestamp_dt    t2m flow  has_trade  \
# 0     2021-10-08 08:00:00  ... 2021-09-30 23:59:59.032  177.0  0.0        NaN
# 1     2021-10-08 08:00:00  ... 2021-10-01 00:00:03.664  176.0  0.0        NaN
# 2     2021-10-08 08:00:00  ... 2021-10-01 00:00:12.072  176.0  0.0        NaN
# 3     2021-10-08 08:00:00  ... 2021-10-01 00:00:15.023  176.0  0.0        NaN
# 4     2021-10-08 08:00:00  ... 2021-10-01 00:01:05.787  176.0  0.0        NaN
# ...                   ...  ...                     ...    ...  ...        ...
# 31301 2021-10-08 08:00:00  ... 2021-10-01 23:59:16.563  153.0  0.0        NaN
# 31302 2021-10-08 08:00:00  ... 2021-10-01 23:59:37.927  153.0  0.0        NaN
# 31303 2021-10-08 08:00:00  ... 2021-10-01 23:59:44.730  153.0  0.0        NaN
# 31304 2021-10-08 08:00:00  ... 2021-10-01 23:59:56.496  153.0  0.0        NaN
# 31305 2021-10-08 08:00:00  ... 2021-10-01 23:59:58.343  153.0  0.0        NaN
#
#        trade_neighbour mid_price  wgt_mid_price  midp_chg  wgtmidp_chg  spread
# 0                False   0.00950       0.009645       NaN          NaN  0.0010
# 1                False   0.00950       0.009441       0.0    -0.021239  0.0010
# 2                False   0.00950       0.009446       0.0     0.000617  0.0010
# 3                False   0.00950       0.009658       0.0     0.022401  0.0010
# 4                False   0.00950       0.009634       0.0    -0.002459  0.0010
# ...                ...       ...            ...       ...          ...     ...
# 31301            False   0.03975       0.039219       0.0    -0.010370  0.0015
# 31302            False   0.03975       0.039254       0.0     0.000900  0.0015
# 31303            False   0.03975       0.039761       0.0     0.012909  0.0015
# 31304            False   0.03975       0.039254       0.0    -0.012745  0.0015
# 31305            False   0.03975       0.039754       0.0     0.012727  0.0015
#
# [31306 rows x 22 columns]

# %% [markdown]
# #### check PERP

# %%
ret_dict, ret_df = quoto_and_trade_analysis( contract='BTC-PERPETUAL',
    date='2021-10-01',
    symbol='BTC-PERPETUAL',
    exchange='deribit',)
# Out:
# processing data BTC-PERPETUAL 2021-10-01 deribit

# %%
ret_dict
# Out:
# {'num_trades': 93564, 'num_midp_chg': 410809, 'num_wgtmidp_chg': 1056088}

# %%
ret_df.head()
# Out:
#   exchange         symbol         timestamp   local_timestamp  ask_amount  \
# 0  deribit  BTC-PERPETUAL  1633046400147000  1633046400187795       12570
# 1  deribit  BTC-PERPETUAL  1633046400401000  1633046400407847       13570
# 2  deribit  BTC-PERPETUAL  1633046401176000  1633046401194893       13570
# 3  deribit  BTC-PERPETUAL  1633046401183000  1633046401208929       13570
# 4  deribit  BTC-PERPETUAL  1633046401184000  1633046401208930       13570
#
#    ask_price  bid_price  bid_amount            timestamp_dt  flow has_trade  \
# 0    43821.5    43821.0      391820 2021-10-01 00:00:00.147   0.0       NaN
# 1    43821.5    43821.0      391820 2021-10-01 00:00:00.401   0.0       NaN
# 2    43821.5    43821.0      396570 2021-10-01 00:00:01.176   0.0       NaN
# 3    43821.5    43821.0      401570 2021-10-01 00:00:01.183   0.0       NaN
# 4    43821.5    43821.0      401820 2021-10-01 00:00:01.184   0.0       NaN
#
#    trade_neighbour  mid_price  wgt_mid_price  midp_chg   wgtmidp_chg
# 0            False   43821.25   43821.015542       NaN           NaN
# 1            False   43821.25   43821.016737       0.0  2.727098e-08
# 2            False   43821.25   43821.016543       0.0 -4.423396e-09
# 3            False   43821.25   43821.016344       0.0 -4.546851e-09
# 4            False   43821.25   43821.016334       0.0 -2.244692e-10
